# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install pymcdm --quiet

import pandas as pd

# Define base and file paths
base_path = "/content/drive/MyDrive/DAINA 3"
file_path = f"{base_path}/final_score_09_11.csv"
# Out:
# Mounted at /content/drive
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.8/128.8 kB 5.0 MB/s eta 0:00:00

# %%
df = pd.read_csv(file_path)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head(3)
# Out:
#        id           left            top          right         bottom  \
# 0  676612  414729.589868  369375.174135  414979.589868  369125.174135
# 1  676611  414729.589868  369625.174135  414979.589868  369375.174135
# 2  676610  414729.589868  369875.174135  414979.589868  369625.174135
#
#    row_index  col_index          area   perimeter  \
# 0        306        855   6656.084138  410.853786
# 1        305        855  28107.499155  755.139192
# 2        304        855  56502.279292  946.460361
#
#                                             geometry  land_score   dem_score  \
# 0  MULTIPOLYGON (((17.7802286 51.1843321, 17.7801...         1.0  177.928571
# 1  MULTIPOLYGON (((17.7818396 51.186814799999986,...         1.0  177.714286
# 2  MULTIPOLYGON (((17.782959 51.188250499999995, ...         1.0  176.648936
#
#      dni_score  temp_score  pvout_score  dso_score  pv_score
# 0  1019.047974         9.4  1114.011963   0.034582  0.811841
# 1  1020.970893         9.4  1114.011963   0.033724  0.816066
# 2  1020.913394         9.4  1114.011963   0.032380  0.821032

# %%
cols_to_drop = ['left', 'top', 'right', 'bottom', 'row_index', 'col_index', 'geometry']
df_reduced = df.drop(columns=cols_to_drop)
print(df_reduced.shape)
df_reduced.head(3)
# Out:
# (321820, 10)
#        id          area   perimeter  land_score   dem_score    dni_score  \
# 0  676612   6656.084138  410.853786         1.0  177.928571  1019.047974
# 1  676611  28107.499155  755.139192         1.0  177.714286  1020.970893
# 2  676610  56502.279292  946.460361         1.0  176.648936  1020.913394
#
#    temp_score  pvout_score  dso_score  pv_score
# 0         9.4  1114.011963   0.034582  0.811841
# 1         9.4  1114.011963   0.033724  0.816066
# 2         9.4  1114.011963   0.032380  0.821032

# %%
df_reduced.info()
df_reduced.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321820 entries, 0 to 321819
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id           321820 non-null  int64
#  1   area         321820 non-null  float64
#  2   perimeter    321820 non-null  float64
#  3   land_score   321820 non-null  float64
#  4   dem_score    321820 non-null  float64
#  5   dni_score    321820 non-null  float64
#  6   temp_score   321820 non-null  float64
#  7   pvout_score  321820 non-null  float64
#  8   dso_score    321820 non-null  float64
#  9   pv_score     321820 non-null  float64
# dtypes: float64(9), int64(1)
# memory usage: 24.6 MB
# id             0
# area           0
# perimeter      0
# land_score     0
# dem_score      0
# dni_score      0
# temp_score     0
# pvout_score    0
# dso_score      0
# pv_score       0
# dtype: int64

# %%
import plotly.express as px

for col in ['area', 'land_score', 'dem_score', 'dni_score','temp_score', 'pvout_score','dso_score','pv_score' ]:
    fig = px.histogram(df_reduced, x=col, nbins=40, title=f"Distribution of {col}", template="plotly_white")
    fig.show()

# %%
import pandas as pd

# Columns you’re analyzing
cols = ['area', 'land_score', 'dem_score', 'dni_score', 'temp_score', 'pvout_score', 'dso_score', 'pv_score']

# Generate descriptive stats
summary = df_reduced[cols].describe(percentiles=[0.05, 0.25, 0.5, 0.75, 0.95]).T

# Add variance and coefficient of variation (optional)
summary['var'] = df_reduced[cols].var().values
summary['cv (%)'] = (df_reduced[cols].std() / df_reduced[cols].mean() * 100).values

# Rename columns for readability
summary = summary.rename(columns={
    '50%': 'median',
    '25%': 'q1 (25th%)',
    '75%': 'q3 (75th%)',
    '5%': 'p5',
    '95%': 'p95'
})

# Round for clarity
summary = summary[['count', 'mean', 'median', 'min', 'q1 (25th%)', 'q3 (75th%)', 'max', 'std', 'var', 'cv (%)']].round(3)

# Display neatly
summary.style.background_gradient(cmap='Blues').set_caption("Statistical Summary of Key Variables")
# Out:
# <style type="text/css">
# #T_c83ce_row0_col0, #T_c83ce_row1_col0, #T_c83ce_row1_col1, #T_c83ce_row1_col2, #T_c83ce_row1_col3, #T_c83ce_row1_col4, #T_c83ce_row1_col5, #T_c83ce_row1_col6, #T_c83ce_row1_col7, #T_c83ce_row1_col8, #T_c83ce_row2_col0, #T_c83ce_row2_col2, #T_c83ce_row2_col3, #T_c83ce_row2_col4, #T_c83ce_row2_col8, #T_c83ce_row3_col0, #T_c83ce_row3_col3, #T_c83ce_row3_col8, #T_c83ce_row3_col9, #T_c83ce_row4_col0, #T_c83ce_row4_col1, #T_c83ce_row4_col2, #T_c83ce_row4_col3, #T_c83ce_row4_col4, #T_c83ce_row4_col5, #T_c83ce_row4_col6, #T_c83ce_row4_col7, #T_c83ce_row4_col8, #T_c83ce_row5_col0, #T_c83ce_row5_col3, #T_c83ce_row5_col8, #T_c83ce_row6_col0, #T_c83ce_row6_col1, #T_c83ce_row6_col2, #T_c83ce_row6_col3, #T_c83ce_row6_col4, #T_c83ce_row6_col5, #T_c83ce_row6_col6, #T_c83ce_row6_col7, #T_c83ce_row6_col8, #T_c83ce_row7_col0, #T_c83ce_row7_col1, #T_c83ce_row7_col2, #T_c83ce_row7_col3, #T_c83ce_row7_col4, #T_c83ce_row7_col5, #T_c83ce_row7_col6, #T_c83ce_row7_col7, #T_c83ce_row7_col8 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c83ce_row0_col1, #T_c83ce_row0_col2, #T_c83ce_row0_col3, #T_c83ce_row0_col4, #T_c83ce_row0_col5, #T_c83ce_row0_col6, #T_c83ce_row0_col7, #T_c83ce_row0_col8, #T_c83ce_row1_col9 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c83ce_row0_col9 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_c83ce_row2_col1, #T_c83ce_row2_col5 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_c83ce_row2_col6 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_c83ce_row2_col7 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_c83ce_row2_col9 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_c83ce_row3_col1, #T_c83ce_row3_col2, #T_c83ce_row3_col5, #T_c83ce_row3_col6, #T_c83ce_row5_col1, #T_c83ce_row5_col2, #T_c83ce_row5_col4, #T_c83ce_row5_col5, #T_c83ce_row5_col6, #T_c83ce_row5_col7, #T_c83ce_row5_col9 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_c83ce_row3_col4 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_c83ce_row3_col7 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_c83ce_row4_col9 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_c83ce_row6_col9 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_c83ce_row7_col9 {
#   background-color: #91c3de;
#   color: #000000;
# }
# </style>
# <table id="T_c83ce" class="dataframe">
#   <caption>Statistical Summary of Key Variables</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c83ce_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_c83ce_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_c83ce_level0_col2" class="col_heading level0 col2" >median</th>
#       <th id="T_c83ce_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_c83ce_level0_col4" class="col_heading level0 col4" >q1 (25th%)</th>
#       <th id="T_c83ce_level0_col5" class="col_heading level0 col5" >q3 (75th%)</th>
#       <th id="T_c83ce_level0_col6" class="col_heading level0 col6" >max</th>
#       <th id="T_c83ce_level0_col7" class="col_heading level0 col7" >std</th>
#       <th id="T_c83ce_level0_col8" class="col_heading level0 col8" >var</th>
#       <th id="T_c83ce_level0_col9" class="col_heading level0 col9" >cv (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c83ce_level0_row0" class="row_heading level0 row0" >area</th>
#       <td id="T_c83ce_row0_col0" class="data row0 col0" >321820.000000</td>
#       <td id="T_c83ce_row0_col1" class="data row0 col1" >61948.020000</td>
#       <td id="T_c83ce_row0_col2" class="data row0 col2" >62500.000000</td>
#       <td id="T_c83ce_row0_col3" class="data row0 col3" >0.010000</td>
#       <td id="T_c83ce_row0_col4" class="data row0 col4" >62500.000000</td>
#       <td id="T_c83ce_row0_col5" class="data row0 col5" >62500.000000</td>
#       <td id="T_c83ce_row0_col6" class="data row0 col6" >62500.000000</td>
#       <td id="T_c83ce_row0_col7" class="data row0 col7" >5035.059000</td>
#       <td id="T_c83ce_row0_col8" class="data row0 col8" >25351816.706000</td>
#       <td id="T_c83ce_row0_col9" class="data row0 col9" >8.128000</td>
#     </tr>
#     <tr>
#       <th id="T_c83ce_level0_row1" class="row_heading level0 row1" >land_score</th>
#       <td id="T_c83ce_row1_col0" class="data row1 col0" >321820.000000</td>
#       <td id="T_c83ce_row1_col1" class="data row1 col1" >0.242000</td>
#       <td id="T_c83ce_row1_col2" class="data row1 col2" >0.010000</td>
#       <td id="T_c83ce_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_c83ce_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_c83ce_row1_col5" class="data row1 col5" >0.402000</td>
#       <td id="T_c83ce_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_c83ce_row1_col7" class="data row1 col7" >0.352000</td>
#       <td id="T_c83ce_row1_col8" class="data row1 col8" >0.124000</td>
#       <td id="T_c83ce_row1_col9" class="data row1 col9" >145.849000</td>
#     </tr>
#     <tr>
#       <th id="T_c83ce_level0_row2" class="row_heading level0 row2" >dem_score</th>
#       <td id="T_c83ce_row2_col0" class="data row2 col0" >321820.000000</td>
#       <td id="T_c83ce_row2_col1" class="data row2 col1" >250.068000</td>
#       <td id="T_c83ce_row2_col2" class="data row2 col2" >177.250000</td>
#       <td id="T_c83ce_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_c83ce_row2_col4" class="data row2 col4" >133.390000</td>
#       <td id="T_c83ce_row2_col5" class="data row2 col5" >302.682000</td>
#       <td id="T_c83ce_row2_col6" class="data row2 col6" >1596.000000</td>
#       <td id="T_c83ce_row2_col7" class="data row2 col7" >182.949000</td>
#       <td id="T_c83ce_row2_col8" class="data row2 col8" >33470.423000</td>
#       <td id="T_c83ce_row2_col9" class="data row2 col9" >73.160000</td>
#     </tr>
#     <tr>
#       <th id="T_c83ce_level0_row3" class="row_heading level0 row3" >dni_score</th>
#       <td id="T_c83ce_row3_col0" class="data row3 col0" >321820.000000</td>
#       <td id="T_c83ce_row3_col1" class="data row3 col1" >989.237000</td>
#       <td id="T_c83ce_row3_col2" class="data row3 col2" >999.595000</td>
#       <td id="T_c83ce_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_c83ce_row3_col4" class="data row3 col4" >974.160000</td>
#       <td id="T_c83ce_row3_col5" class="data row3 col5" >1014.117000</td>
#       <td id="T_c83ce_row3_col6" class="data row3 col6" >1040.597000</td>
#       <td id="T_c83ce_row3_col7" class="data row3 col7" >52.483000</td>
#       <td id="T_c83ce_row3_col8" class="data row3 col8" >2754.415000</td>
#       <td id="T_c83ce_row3_col9" class="data row3 col9" >5.305000</td>
#     </tr>
#     <tr>
#       <th id="T_c83ce_level0_row4" class="row_heading level0 row4" >temp_score</th>
#       <td id="T_c83ce_row4_col0" class="data row4 col0" >321820.000000</td>
#       <td id="T_c83ce_row4_col1" class="data row4 col1" >8.846000</td>
#       <td id="T_c83ce_row4_col2" class="data row4 col2" >9.400000</td>
#       <td id="T_c83ce_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_c83ce_row4_col4" class="data row4 col4" >8.400000</td>
#       <td id="T_c83ce_row4_col5" class="data row4 col5" >9.600000</td>
#       <td id="T_c83ce_row4_col6" class="data row4 col6" >9.900000</td>
#       <td id="T_c83ce_row4_col7" class="data row4 col7" >1.238000</td>
#       <td id="T_c83ce_row4_col8" class="data row4 col8" >1.533000</td>
#       <td id="T_c83ce_row4_col9" class="data row4 col9" >13.996000</td>
#     </tr>
#     <tr>
#       <th id="T_c83ce_level0_row5" class="row_heading level0 row5" >pvout_score</th>
#       <td id="T_c83ce_row5_col0" class="data row5 col0" >321820.000000</td>
#       <td id="T_c83ce_row5_col1" class="data row5 col1" >1089.825000</td>
#       <td id="T_c83ce_row5_col2" class="data row5 col2" >1097.942000</td>
#       <td id="T_c83ce_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_c83ce_row5_col4" class="data row5 col4" >1084.427000</td>
#       <td id="T_c83ce_row5_col5" class="data row5 col5" >1111.821000</td>
#       <td id="T_c83ce_row5_col6" class="data ro

# %%
df_reduced = df_reduced.drop(columns=["area"])

# %%
# #Inverting pvscore because DSO (tauron) said that farther away from existing pv farms is better
# df_reduced["pv_score"] = 1 - df_reduced["pv_score"]

# %%
import pandas as pd
import plotly.express as px


corr_cols = ['land_score', 'dem_score', 'dni_score',
             'temp_score', 'pvout_score', 'dso_score', 'pv_score']

corr_matrix = df_reduced[corr_cols].corr()

# Display numeric correlation table
display(corr_matrix.round(3))

fig = px.imshow(
    corr_matrix,
    text_auto=True,
    color_continuous_scale='RdBu_r',
    title='Correlation Matrix of MCDM Criteria',
    aspect='auto',
    zmin=-1, zmax=1
)
fig.update_layout(template='plotly_white')
fig.show()
# Out:
#              land_score  dem_score  dni_score  temp_score  pvout_score  \
# land_score        1.000     -0.210      0.285       0.178        0.151
# dem_score        -0.210      1.000     -0.438      -0.844       -0.168
# dni_score         0.285     -0.438      1.000       0.462        0.355
# temp_score        0.178     -0.844      0.462       1.000        0.614
# pvout_score       0.151     -0.168      0.355       0.614        1.000
# dso_score         0.003      0.031      0.002      -0.011        0.078
# pv_score          0.022      0.127      0.036      -0.073        0.096
#
#              dso_score  pv_score
# land_score       0.003     0.022
# dem_score        0.031     0.127
# dni_score        0.002     0.036
# temp_score      -0.011    -0.073
# pvout_score      0.078     0.096
# dso_score        1.000     0.350
# pv_score         0.350     1.000
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dd6f5439-45ee-4622-8e3c-82bf347c4b46" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd6f5439-45ee-4622-8e3c-82bf347c4b46")) {                    Plotly.newPlot(                        "dd6f5439-45ee-4622-8e3c-82bf347c4b46",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["land_score","dem_score","dni_score","temp_score","pvout_score","dso_score","pv_score"],"y":["land_score","dem_score","dni_score","temp_score","pvout_score","dso_score","pv_score"],"z":[[1.0,-0.20981342551383994,0.2845599352300685,0.177776647420525,0.1507734652715412,0.003354389779624526,0.022015288126057474],[-0.20981342551383994,1.0,-0.43814172686867386,-0.8439252486973053,-0.1679371982752741,0.03089219261685108,0.12673744576835116],[0.2845599352300685,-0.43814172686867386,1.0,0.46216628819371297,0.3548398913305209,0.002225934809573511,0.03620862855256163],[0.177776647420525,-0.8439252486973053,0.46216628819371297,1.0,0.614075228755627,-0.010530391277095402,-0.07335250828169082],[0.1507734652715412,-0.1679371982752741,0.3548398913305209,0.614075228755627,1.0,0.07776838466596446,0.09596993199705364],[0.003354389779624526,0.03089219261685108,0.002225934809573511,-0.010530391277095402,0.07776838466596446,1.0,0.35031570785293314],[0.022015288126057474,0.12673744576835116,0.03620862855256163,-0.07335250828169082,0.09596993199705364,0.35031570785293314,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3 ...
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['land_score'].plot(kind='hist', bins=20, title='land_score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['dem_score'].plot(kind='hist', bins=20, title='dem_score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['dni_score'].plot(kind='hist', bins=20, title='dni_score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['temp_score'].plot(kind='hist', bins=20, title='temp_score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='land_score', y='dem_score', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='dem_score', y='dni_score', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='dni_score', y='temp_score', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='temp_score', y='pvout_score', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['land_score'].plot(kind='line', figsize=(8, 4), title='land_score')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['dem_score'].plot(kind='line', figsize=(8, 4), title='dem_score')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['dni_score'].plot(kind='line', figsize=(8, 4), title='dni_score')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['temp_score'].plot(kind='line', figsize=(8, 4), title='temp_score')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# Out:
# ERROR: Ignored the following yanked versions: 1.0.1
# ERROR: Could not find a version that satisfies the requirement pymcdm==1.6.8 (from versions: 1.0.0, 1.0.1a0, 1.0.2, 1.0.3, 1.0.3.post1, 1.0.3.post2, 1.0.4, 1.0.5, 1.1.0, 1.2.0, 1.2.1, 1.3.0, 1.3.1)
# ERROR: No matching distribution found for pymcdm==1.6.8
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-831737898.py in <cell line: 0>()
#       5 from pymcdm import weights as wts
#       6
# ----> 7 print("pymcdm version:", pymcdm.__version__)
#       8 print("weights module has:", [n for n in dir(wts) if not n.startswith("_")])
#
# AttributeError: module 'pymcdm' has no attribute '__version__'
